# %% [markdown]
# <a href="https://colab.research.google.com/github/Miss-Pradhi/ML-LAB-Assignment/blob/main/LAB-2_Central_Tendency_and_Dispersion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## A) Central Tendencies: Mean, Median, and Mode
#
# To understand the typical value of our numerical data, we will calculate the mean, median, and mode for `feature_A`, `feature_B`, and `feature_D`.

# %%
import pandas as pd

numerical_cols = ['feature_A', 'feature_B', 'feature_D']

print("### Central Tendencies:\n")

for col in numerical_cols:
    mean_val = df[col].mean()
    median_val = df[col].median()
    mode_val = df[col].mode().tolist() # mode() can return multiple values

    print(f"--- {col} ---")
    print(f"Mean: {mean_val:.2f}")
    print(f"Median: {median_val:.2f}")
    print(f"Mode: {mode_val}")
    print("\n")
# Out:
# ### Central Tendencies:
#
# --- feature_A ---
# Mean: 50.96
# Median: 51.47
# ...

# %% [markdown]
# ## B) Measures of Dispersion
#
# To understand the spread or variability of our numerical data, we will calculate the standard deviation, variance, range, and interquartile range (IQR) for `feature_A`, `feature_B`, and `feature_D`.

# %%
import numpy as np

numerical_cols = ['feature_A', 'feature_B', 'feature_D']

print("### Measures of Dispersion:\n")

for col in numerical_cols:
    std_dev = df[col].std()
    variance = df[col].var()
    data_range = df[col].max() - df[col].min()
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    iqr = Q3 - Q1

    print(f"--- {col} ---")
    print(f"Standard Deviation: {std_dev:.2f}")
    print(f"Variance: {variance:.2f}")
    print(f"Range: {data_range:.2f}")
    print(f"IQR (Interquartile Range): {iqr:.2f}")
    print("\n")
# Out:
# ### Measures of Dispersion:
#
# --- feature_A ---
# Standard Deviation: 30.15
# Variance: 908.94
# Range: 97.50
# IQR (Interquartile Range): 53.88
#
#
# --- feature_B ---
# Standard Deviation: 2.91
# Variance: 8.45
# Range: 8.00
# IQR (Interquartile Range): 6.00
#
#
# --- feature_D ---
# Standard Deviation: 14.10
# Variance: 198.85
# Range: 101.85
# IQR (Interquartile Range): 1.46
